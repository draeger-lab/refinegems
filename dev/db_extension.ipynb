# %% [markdown]
# # Code & example to update refineGEMs' internal database
# The following code transforms a human-readable TSV file in the FILE_DIRECTORY (I) into the data format required to update the internal database of refineGEMs (II & III).

# %%
from refinegems.classes.medium import update_db_multi, updated_db_to_schema
import pandas as pd
import numpy as np
import ntpath
import os
# Out:
# /Users/brune/miniconda3/envs/sprg/lib/python3.10/site-packages/pydantic/_internal/_config.py:322: UserWarning: Valid config keys have changed in V2:
# * 'underscore_attrs_are_private' has been removed
#   warnings.warn(message, UserWarning)

# %% [markdown]
# ## (I) File directory
# The file directory needs to be specified here. All files from this directory will be used to generate new TSV files compatible with the database.

# %%
FILE_DIRECTORY = './oils_for_artificial_sebum/' #'../../../'

# %% [markdown]
# ## (II) Transformation of human-readable TSV files to database-readable files
# The following function `transform_medium_tsv_table_for_update` does the main job in transforming the TSV files into database-readable TSV files. </br>
# This function is currently only setting up the input for the database tables 'medium2substance' and 'substance2db'. </br>
# The code cell underneath the function definition cell specifies that only files ending with '_substances.tsv' should be transformed.

# %%
def transform_medium_tsv_table_for_update(table_path: str, file_directory: str):
   """Transforms a TSV table containing a medium/subset definition into (a) TSV file(s) usable 
   with the medium.py setup to be used to automatically update the database

   Args:
       - table_path (str): Path to the TSV file defining a medium/ subset
       - file_directory (str): Path to the current workspace directory
   """
   table_path = f'{file_directory}{table_path}'
   # Get medium name & DataFrame
   medium_or_subset_name_list = ntpath.basename(table_path.replace('.tsv', '')).split('_')
   medium_or_subset_name = medium_or_subset_name_list[0]
   medium_or_subset = medium_or_subset_name_list[1]
   if not medium_or_subset in ['medium', 'subset']:
      print('No  medium/subset file was provided. At least no medium/subset was specified in the file name.')
      return
   
   # Get all necessary names from file name
   table_name = 'medium2substance' if medium_or_subset == 'medium' else 'subset2substance'
   flux_or_percent = 'flux' if medium_or_subset == 'medium' else 'percent'
   mos_df = pd.read_csv(table_path, sep='\t')
   
   # Rename relevant & drop unnecessary columns
   mos_df.drop('formula', axis=1, inplace=True)
   mos_df.rename({'name': 'substance'}, axis=1, inplace=True)
   
   # Add new columns medium_or_subset & 'table' to mos table
   mos2s_df = mos_df.copy() # Copy dataframe to avoid trouble with substance table update
   mos2s_df[medium_or_subset] = medium_or_subset_name
   mos2s_df['table'] = table_name
   
   # Add conditions column to mos table
   mos2s_df['conditions'] = mos2s_df.apply(lambda row: f'substance={row["substance"]};{medium_or_subset}={row[medium_or_subset]}', axis=1)
   mos2s_df.drop(['substance', medium_or_subset], axis=1, inplace=True)
   
   ### Get all relevant columns to update flux/percent if present
   if not mos2s_df[flux_or_percent].empty:
      mos2s_flux_or_percent_df = mos2s_df[[flux_or_percent, 'table', 'conditions']].copy()
      # Rename new_value to 'new_value'
      mos2s_flux_or_percent_df.rename({flux_or_percent: 'new_value'}, axis=1, inplace=True)
      mos2s_flux_or_percent_df['column'] = flux_or_percent
      # Extract mos2s table
      file_substring = 'm2s' if medium_or_subset == 'medium' else 's2s'
      mos2s_flux_or_percent_df.to_csv(f'{file_directory}{medium_or_subset_name}_{file_substring}_{flux_or_percent}_update.tsv', sep='\t', index=False)
      
   ### Get all relevant columns to update source if present
   if not mos2s_df['source'].empty:
      mos2s_source_df = mos2s_df[['source', 'table', 'conditions']].copy()
      # Rename 'source' to 'new_value'
      mos2s_source_df.rename({'source': 'new_value'}, axis=1, inplace=True)
      mos2s_source_df['column'] = 'source'
      # Extract mos2s table
      file_substring = 'm2s' if medium_or_subset == 'medium' else 's2s'
      mos2s_source_df.to_csv(f'{file_directory}{medium_or_subset_name}_{file_substring}_source_update.tsv', sep='\t', index=False)
      
   if mos2s_df[flux_or_percent].empty or mos2s_df['source'].empty: print('No updatable column for a medium/subset update present.')
   
   if len(mos_df.columns) > 4:
      ### Get the s2db table for update, if possible
      s2db_df = mos_df.drop([flux_or_percent,'source'], axis=1)
      
      # Merge VMH & BiGG if they have the same ID & Column does not already exist
      if not 'BiGG+VMH' in s2db_df.columns:
         # Create new column 'BiGG+VMH'
         s2db_df['BiGG+VMH'] = np.NaN
         
         # Merge VMH & BiGG column for same IDs & Remove original entries
         def merge_BiGG_VMH(row: pd.Series):
            if (row['BiGG'] == (row['VMH'])): # | (row["BiGG"].isna() & row["VMH"].isna())
               row['BiGG+VMH'] = row['BiGG']
               row['BiGG'] = np.NaN # Remove entry from column
               row['VMH'] = np.NaN # Remove entry from column
            else:
               row['BiGG+VMH'] = np.NaN
            return row
      
         s2db_df = s2db_df.apply(merge_BiGG_VMH, axis=1)
      
      # Transform table into long format
      s2db_df = pd.melt(s2db_df, id_vars='substance', var_name='db_type', value_name='db_id', ignore_index=True)
      
      # Remove all NaNs
      s2db_df.dropna(inplace=True)
      
      # Add new columns table & column to s2db table
      s2db_df['table'] = 'substance2db'
      s2db_df['column'] = 'substance_id, db_id, db_type'
      
      # Create 'new_value' from 'db_type' & 'db_id'
      s2db_df['new_value'] = s2db_df.apply(lambda row: f'{row["db_id"]}, {row["db_type"]}', axis=1)
      s2db_df.drop(['db_type', 'db_id'], axis=1, inplace=True)
      
      # Add conditions column to s2db table
      s2db_df['conditions'] = s2db_df.apply(lambda row: f'substance={row["substance"]}', axis=1)
      s2db_df.drop('substance', axis=1, inplace=True)
      
      # Extract s2db table
      s2db_df.to_csv(f'{file_directory}{medium_or_subset_name}_s2db_update.tsv', sep='\t', index=False)

# %%
for files in os.listdir(FILE_DIRECTORY):
    if files.endswith('_substances.tsv'):
        if 'already' in files: continue
        print(files)
        transform_medium_tsv_tables_for_update(f'{FILE_DIRECTORY}{files}', FILE_DIRECTORY)
    else:
        continue
# Out:
# RPMI_substances.tsv
# CasA_subset_substances.tsv
# CGXII_substances.tsv
# dGMM_substances.tsv
# M9_substances.tsv
# CasA_medium_substances.tsv
# MP-AU_substances.tsv
# SNM3_substances.tsv
# LB_substances.tsv

# %% [markdown]
# ## (III) Add data from the database-readable TSV file to the database
# The following code iterates over all newly generated TSV files and updates the database tables 'medium2substance' and 'substance2db' accordingly.

# %%
for files in os.listdir(FILE_DIRECTORY):
    if files.endswith('_update.tsv'):
            print(files)
            update = True if 'm2s' in files else False
            df = pd.read_csv(files, sep='\t')
            update_db_multi(df, update_entries=update)
    else:
        continue
# Out:
# CasA_subset_substances_for_s2db_update.tsv
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=cpd00395, SEED, condition=substance=L-Cysteate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=MNXM713, MetaNetX, condition=substance=L-Cysteate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=Lcyst, BiGG+VMH, condition=substance=L-Cysteate
# CasA_medium_substances_for_m2s_update.tsv
# RPMI_substances_for_m2s_update.tsv
# SNM3_substances_for_m2s_update.tsv
# MP-AU_substances_for_m2s_update.tsv
# CGXII_substances_for_m2s_update.tsv
# M9_substances_for_m2s_update.tsv
# CasA_subset_substances_for_m2s_update.tsv
# CGXII_substances_for_s2db_update.tsv
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= oh1, BiGG+VMH, condition=substance=Hydroxide
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=cpd15275, SEED, condition=substance=Hydroxide
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=MNXM02, MetaNetX, condition=substance=Hydroxide
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C01328, KEGG, condition=substance=Hydroxide
# dGMM_substances_for_m2s_update.tsv
# dGMM_substances_for_s2db_update.tsv
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=cpd24344, SEED, condition=substance=Aluminium(III) cation [Al(3+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=cpd11640, SEED, condition=substance=Dihydrogen [H2]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=MNXM729498, MetaNetX, condition=substance=Aluminium(III) cation [Al(3+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=MNXM1108018, MetaNetX, condition=substance=Dihydrogen [H2]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=h2, BiGG+VMH, condition=substance=Dihydrogen [H2]
# LB_substances_for_m2s_update.tsv
# CasA_medium_substances_for_s2db_update.tsv
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=Lcyst, BiGG+VMH, condition=substance=L-Cysteate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=cpd00395, SEED, condition=substance=L-Cysteate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=MNXM713, MetaNetX, condition=substance=L-Cysteate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00506, KEGG, condition=substance=L-Cysteate

# %% [markdown]
# ## Update Schema with updated database
# !Be careful to  check the changes between the current SQL Schema file and the new one!

# %%
updated_db_to_schema()

# %%
transform_medium_tsv_tables_for_update('artSe_subset.tsv', FILE_DIRECTORY)

# %%
s2s_percent_df = pd.read_csv('./oils_for_artificial_sebum/artSe_s2s_percent_update.tsv', sep='\t')
update_db_multi(s2s_percent_df, update_entries=False)
#s2s_source_df = pd.read_csv('./oils_for_artificial_sebum/artSe_s2s_source_update.tsv')
substances_df = pd.read_csv('./oils_for_artificial_sebum/artSe_s2db_update.tsv', sep='\t')
update_db_multi(substances_df, update_entries=False)
# Out:
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= chsterol, BiGG, condition=substance=Cholesterol
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= ocdcea, BiGG, condition=substance=Octadecenoate [Oleic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= ttdca, BiGG, condition=substance=Tetradecanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= ddca, BiGG, condition=substance=Dodecanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= hdca, BiGG, condition=substance=Hexadecanoate [Palmitic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= dca, BiGG, condition=substance=Decanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= hpdca, BiGG, condition=substance=Margarate [Heptadecanoate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= ocdca, BiGG, condition=substance=Octadecanoate [Stearic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= arach, BiGG, condition=substance=Arachidic acid
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= docosac, BiGG, condition=substance=Behenate [Docosanoate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= lgnc, BiGG, condition=substance=Tetracosanoate [Lignocerate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= hdcea, BiGG, condition=substance=Hexadecenoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= lnlc, BiGG, condition=substance=Linoleic acid
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= fe2, BiGG, condition=substance=Iron(II) cation [Fe(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= fe3, BiGG, condition=substance=Iron(III) cation [Fe(3+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= h2o, BiGG, condition=substance=Water [H2O]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= avite1, BiGG, condition=substance=alpha-Tocopherol
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= phllqne, BiGG, condition=substance=Phylloquinone [Vitamin K1]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= k, BiGG, condition=substance=Potassium(I) cation [K(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= na1, BiGG, condition=substance=Sodium(I) cation [Na(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= but, BiGG, condition=substance=Butyrate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= octa, BiGG, condition=substance=Octanoate [Caprylic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= ptdca, BiGG, condition=substance=Pentadecanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= zn2, BiGG, condition=substance=Zinc(II) cation [Zn(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value= arachd, BiGG, condition=substance=Arachidonate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=MNXM11802, MetaNetX, condition=substance=Margarate [Heptadecanoate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=chsterol, VMH, condition=substance=Cholesterol
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ocdcea, VMH, condition=substance=Octadecenoate [Oleic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ttdca, VMH, condition=substance=Tetradecanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ddca, VMH, condition=substance=Dodecanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=hdca, VMH, condition=substance=Hexadecanoate [Palmitic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=dca, VMH, condition=substance=Decanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=hpdca, VMH, condition=substance=Margarate [Heptadecanoate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ocdca, VMH, condition=substance=Octadecanoate [Stearic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=arach, VMH, condition=substance=Arachidic acid
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=docosac, VMH, condition=substance=Behenate [Docosanoate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=lgnc, VMH, condition=substance=Tetracosanoate [Lignocerate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=hdcea, VMH, condition=substance=Hexadecenoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=lnlc, VMH, condition=substance=Linoleic acid
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=fe2, VMH, condition=substance=Iron(II) cation [Fe(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=fe3, VMH, condition=substance=Iron(III) cation [Fe(3+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=h2o, VMH, condition=substance=Water [H2O]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=avite1, VMH, condition=substance=alpha-Tocopherol
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=phyQ, VMH, condition=substance=Phylloquinone [Vitamin K1]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=k, VMH, condition=substance=Potassium(I) cation [K(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=na1, VMH, condition=substance=Sodium(I) cation [Na(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=but, VMH, condition=substance=Butyrate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=octa, VMH, condition=substance=Octanoate [Caprylic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ptdca, VMH, condition=substance=Pentadecanoate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=zn2, VMH, condition=substance=Zinc(II) cation [Zn(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=arachd, VMH, condition=substance=Arachidonate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ca2, BiGG+VMH, condition=substance=Calcium(II) cation [Ca(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=chol, BiGG+VMH, condition=substance=Choline

# %%
def transform_substance2db_tsv_table_for_update(table_path: str, file_directory: str):
   """Transforms a TSV table containing a medium/subset definition into (a) TSV file(s) usable 
   with the medium.py setup to be used to automatically update the database

   Args:
       - table_path (str): Path to the TSV file defining a medium/ subset
       - file_directory (str): Path to the current workspace directory
   """
   table_path = f'{file_directory}{table_path}'
   s2db_df = pd.read_csv(table_path, sep='\t')

   # Merge VMH & BiGG if they have the same ID & Column does not already exist
   if not 'BiGG+VMH' in s2db_df.columns:
      # Create new column 'BiGG+VMH'
      s2db_df['BiGG+VMH'] = np.NaN
      # Merge VMH & BiGG column for same IDs & Remove original entries
      def merge_BiGG_VMH(row: pd.Series):
         if (row['BiGG'] == (row['VMH'])): # | (row["BiGG"].isna() & row["VMH"].isna())
            row['BiGG+VMH'] = row['BiGG']
            row['BiGG'] = np.NaN # Remove entry from column
            row['VMH'] = np.NaN # Remove entry from column
         else:
            row['BiGG+VMH'] = np.NaN
         return row
      s2db_df = s2db_df.apply(merge_BiGG_VMH, axis=1)

   # Transform table into long format
   s2db_df = pd.melt(s2db_df, id_vars='substance', var_name='db_type', value_name='db_id', ignore_index=True)
   
   # Remove all NaNs
   s2db_df.dropna(inplace=True)
   
   # Add new columns table & column to s2db table
   s2db_df['table'] = 'substance2db'
   s2db_df['column'] = 'substance_id, db_id, db_type'
   
   # Create 'new_value' from 'db_type' & 'db_id'
   s2db_df['new_value'] = s2db_df.apply(lambda row: f'{row["db_id"]}, {row["db_type"]}', axis=1)
   s2db_df.drop(['db_type', 'db_id'], axis=1, inplace=True)
   
   # Add conditions column to s2db table
   s2db_df['conditions'] = s2db_df.apply(lambda row: f'substance={row["substance"]}', axis=1)
   s2db_df.drop('substance', axis=1, inplace=True)
   
   # Extract s2db table
   s2db_df.to_csv(f'{file_directory}{ntpath.basename(table_path.replace(".tsv", ""))}_s2db_update.tsv', sep='\t', index=False)

# %%
transform_substance2db_tsv_table_for_update('SNM3.tsv', '/Users/brune/Documents/10_Code/possible-modules-for-rg/')

# %%
substances_df = pd.read_csv('/Users/brune/Documents/10_Code/possible-modules-for-rg/SNM3_s2db_update.tsv', sep='\t')
update_db_multi(substances_df, update_entries=False)
# Out:
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=pnto__R, BiGG, condition=substance=3-[(2R)-2,4-Dihydroxy-3,3-dimethylbutanamido]propanoate [Pantothenate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=glc__D, BiGG, condition=substance=D-Glucose
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=orn__D, BiGG, condition=substance=D-Ornithine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ala__L, BiGG, condition=substance=L-Alanine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=arg__L, BiGG, condition=substance=L-Arginine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=cys__L, BiGG, condition=substance=L-Cysteine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=glu__L, BiGG, condition=substance=L-Glutamate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=his__L, BiGG, condition=substance=L-Histidine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=leu__L, BiGG, condition=substance=L-Leucine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=lys__L, BiGG, condition=substance=L-Lysine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=orn__L, BiGG, condition=substance=L-Ornithine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=phe__L, BiGG, condition=substance=L-Phenylalanine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=pro__L, BiGG, condition=substance=L-Proline
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ser__L, BiGG, condition=substance=L-Serine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=thr__L, BiGG, condition=substance=L-Threonine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=trp__L, BiGG, condition=substance=L-Tryptophan
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=val__L, BiGG, condition=substance=L-Valine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=male, BiGG, condition=substance=Maleate
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ni2, BiGG, condition=substance=Nickel(II) cation [Ni(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=nicnt, BiGG, condition=substance=Pyridine-3-carboxylate [Niacin]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=mobd, BiGG, condition=substance=Tetraoxidomolybdate(VI) [Molybdate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=b12, BiGG, condition=substance=Vitamin B12
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00864, KEGG, condition=substance=3-[(2R)-2,4-Dihydroxy-3,3-dimethylbutanamido]propanoate [Pantothenate]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00120, KEGG, condition=substance=Biotin
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00076, KEGG, condition=substance=Calcium(II) cation [Ca(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00698, KEGG, condition=substance=Chloride [Cl(-)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00175, KEGG, condition=substance=Cobalt(II) cation [Co(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00031, KEGG, condition=substance=D-Glucose
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00007, KEGG, condition=substance=Dioxygen [O2]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00037, KEGG, condition=substance=Glycine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C00080, KEGG, condition=substance=Hydrogen [H(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=C
2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=o2, BiGG+VMH, condition=substance=Dioxygen [O2]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=gly, BiGG+VMH, condition=substance=Glycine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=h, BiGG+VMH, condition=substance=Hydrogen [H(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=mg2, BiGG+VMH, condition=substance=Magnesium(II) cation [Mg(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=mn2, BiGG+VMH, condition=substance=Manganese(II) cation [Mn(2+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=pi, BiGG+VMH, condition=substance=Phosphate [PO4(3-)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=k, BiGG+VMH, condition=substance=Potassium(I) cation [K(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=pyr, BiGG+VMH, condition=substance=Pyruvate [Pyruvic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=ribflv, BiGG+VMH, condition=substance=Riboflavin
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=na1, BiGG+VMH, condition=substance=Sodium(I) cation [Na(+)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=succ, BiGG+VMH, condition=substance=Succinate [Succinic acid]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=so4, BiGG+VMH, condition=substance=Sulfate [SO4(2-)]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=thm, BiGG+VMH, condition=substance=Thiamine
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=urea, BiGG+VMH, condition=substance=Urea
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=h2o, BiGG+VMH, condition=substance=Water [H2O]
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=zn2, BiGG+VMH, condition=substance=Zinc(II) cation [Zn(2+)]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 substances_df = pd.read_csv('/Users/brune/Documents/10_Code/possible-modules-for-rg/SNM3_s2db_update.tsv', sep='\t')
#       2 update_db_multi(substances_df, update_entries=False)
# ----> 4 updated_db_to_schema()
#
# File ~/Documents/10_Code/refinegems/build/__editable__.refineGEMs-1.4.2-py3-none-any/refinegems/classes/medium.py:1652, in updated_db_to_schema(directory)
#    1649 counter = 0 # To count rows in newly generated file
#    1651 conn = sqlite3.connect(PATH_TO_DB)
# -> 1652 with open((f'{directory}updated_media_db.sql'), 'w') as file:
#    1653     for line in iterdump(conn):
#    1654         if not (any(map(lambda x: x in line, NOT_TO_SCHEMA))):
#
# FileNotFoundError: [Errno 2] No such file or directory: './src/refinegems/data/database/updated_media_db.sql'

# %%
updated_db_to_schema('/Users/brune/Documents/10_Code/refinegems/src/refinegems/data/database')

# %%
from refinegems.classes.medium import update_db_multi, updated_db_to_schema
import pandas as pd

substances_df = pd.read_csv('/Users/brune/Documents/10_Code/possible-modules-for-rg/media-defs/SNM3_s2db_update_test.tsv', sep='\t')
update_db_multi(substances_df, update_entries=False)
# Out:
# ['BiGG', 'VMH']
# ['BiGG', 'VMH']
# []
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=so4, BiGG+VMH, condition=substance=Sulfate [SO4(2-)]
# ['BiGG', 'VMH']
# ['BiGG', 'VMH']
# []
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=thm, BiGG+VMH, condition=substance=Thiamine
# ['BiGG', 'VMH']
# ['BiGG', 'VMH']
# []
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=urea, BiGG+VMH, condition=substance=Urea
# ['BiGG', 'VMH']
# ['BiGG', 'VMH']
# []
# UNIQUE constraint failed: substance2db.substance_id, substance2db.db_id
# Ocurred with: column=substance_id, db_id, db_type, new_value=h2o, BiGG+VMH, condition=substance=Water [H2O]
# /Users/brune/miniconda3/envs/sprg/lib/python3.10/site-packages/pydantic/_internal/_config.py:322: UserWarning: Valid config keys have changed in V2:
# * 'underscore_attrs_are_private' has been removed
#   warnings.warn(message, UserWarning)
