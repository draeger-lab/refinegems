# %%
from refinegems.classes.medium import generate_docs_for_subset
from refinegems.utility.io import load_a_table_from_database

# %%
# Get all available subsets from the database
available_subsets = load_a_table_from_database('subset', False)['name'].tolist()
available_subsets
# Out:
# ['CasA', 'protAA', 'artSe', 'DiReM', 'Tween 80™']

# %%
# Generate documentation tables for all available subsets
for subset in available_subsets:
    generate_docs_for_subset(subset)
